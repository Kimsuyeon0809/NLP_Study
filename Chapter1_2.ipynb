# %% [markdown]
# page 40~48

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/MyDrive/NLP_ebook
# Out:
# /content/drive/MyDrive/NLP_ebook

# %%
cd data
# Out:
# /content/drive/MyDrive/NLP_ebook/data

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np
# Out:
# <ipython-input-16-434bd75148fc>:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %% [markdown]
# # 1. 데이터 살펴보기
# - 프로파일링 한 리포트 살펴보기
# - overview :개요 (feature 수, 총 샘플 수, 결측값 수와 비율, 중복인 행 수)
# - Variables : 각 feature 별 unique한 값에 대한 통계치 (유니크한 값의 수, 결측값)

# %%
data = pd.read_csv('spam.csv', encoding='latin1')
data.head(3)
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN

# %%
pr=data.profile_report()
pr
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-03-05 02:27:37.701659&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # 2. 머신러닝 워크플로우
# - 전반적인 처리 과정
# 1. 수집 (말뭉치 = 코퍼스 : 자연어 데이터)
# 2. 점검 및 탐색 (탐색적 데이터 분석, EDA) : 데이터 구조, 노이즈, 어떻게 정제할지, 내재하는 구조적 관계 파악, 간단한 시각화, 통계 테스트
# 3. 전처리 및 정제 : 자연어 처리의 경우 토큰화, 정제, 정규화, 불용어 제거 등
# 4. 모델링 및 훈련 : 알고리즘 선택해 모델링, 훈련용
# 데이터로 학습
# 5. 성능 평가
# 6. 배포
